# %% [markdown]
# # Iniciando a Exploratória de Dados (EDA) - Perfil de Inscritos
#
# Este notebook deve ser usado para as análises iniciais:
# 1. Ingestão de relatórios externos (CSV/Excel).
# 2. Limpeza de campos nulos (Documentos/Memorandos).
# 3. Cruzamento com dados de Bairros e IDH.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configurações de visualização
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Carregando Dados Locais
# Coloque os relatórios na pasta `/data/raw`.

# %%
# df_raw = pd.read_csv('../data/raw/relatorio_inscritos.csv')
# df_raw.head()

# %% [markdown]
# ## 2. Validação de Preenchimento
# Identificando nulos em campos cruciais (Documentos/Memorandos).

# %%
# print("Nulos por coluna:\n", df_raw.isnull().sum())
# sns.heatmap(df_raw.isnull(), cbar=False)
